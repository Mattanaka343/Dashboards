# %%
fig1  = px.histogram(
        df,
        x = 'Duration(s)',
        nbins = 30,
        title = 'Recording Duration Distribution'
    )

    mean_duration = df['Duration(s)'].mean()
    
    fig1.add_vline(
        x = mean_duration,
        line_dash = 'dot',
        line_color = 'red'
    )

    fig2 = px.pie(
        df,
        names = 'SkillName',
        title = 'Skill Distribution'
    )


    df_valid = df[df['IsValid']==True]
    df_valid['Duration(h)'] = df_valid['Duration(s)']/3600
    df_bar1 = df_valid.groupby('SkillName',as_index=False)["Duration(h)"].sum()

    fig3 = px.bar(
        df_bar1,
        x = 'Duration(h)',
        y = 'SkillName',
        title = 'Valid Hours Collected per Skill',
        labels = {
            'x':'Hours Collected',
            'y':'Skill Name'
        }
    )

    fig3.add_vline(
        x = 30,
        line_dash = "dot",
        line_color = 'red'
    )

    df_bar2 = df_valid.groupby('Operator',as_index=False)["Duration(h)"].sum()

    fig4 = px.bar(
        df_bar2,
        x = 'Duration(h)',
        y = 'Operator',
        title = 'Valid Hours Collected Per Operator',
        labels = {
            'x':'Hours Collected',
            'y': 'Operator'
        }
    )

    df_valid['Start_Time'] = df_valid['Start_Time'].dt.date
    df_timeline = df_valid.groupby('Start_Time', as_index = False)['Duration(h)'].sum()

    fig5 = px.line(
        df_timeline,
        x = 'Start_Time',
        y = 'Duration(h)',
        title = 'Timeline of hours collected',
        labels = {
            'x': 'Date',
            'y': 'Hours Collected'
        }
    )

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('Data/general_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9348 entries, 0 to 9347
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   IsValid      9348 non-null   str
#  1   Station      9348 non-null   str
#  2   SkillID      9348 non-null   str
#  3   BagName      9348 non-null   str
#  4   Operator     9348 non-null   str
#  5   Duration(s)  9348 non-null   float64
#  6   Start_Time   9348 non-null   str
#  7   SkillName    9348 non-null   str
# dtypes: float64(1), str(7)
# memory usage: 1.4 MB

# %%
df['IsValid'].unique()
# Out:
# <ArrowStringArray>
# ['False', 'True', 'TRUE', 'FALSE', 'UNKNOWN']
# Length: 5, dtype: str

# %%
df['IsValid'] = df['IsValid'].replace({'TRUE':'True',
                                                       'FALSE':'False',
                                                       'UNKNOWN':'False'})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9348 entries, 0 to 9347
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   IsValid      9348 non-null   str
#  1   Station      9348 non-null   str
#  2   SkillID      9348 non-null   str
#  3   BagName      9348 non-null   str
#  4   Operator     9348 non-null   str
#  5   Duration(s)  9348 non-null   float64
#  6   Start_Time   9348 non-null   str
#  7   SkillName    9348 non-null   str
# dtypes: float64(1), str(7)
# memory usage: 1.4 MB

# %%
df['IsValid'] = df['IsValid'].map({'True':True, 'False':False})

# %%
df['IsValid'].unique()
# Out:
# <ArrowStringArray>
# ['False', 'True']
# Length: 2, dtype: str

# %%
bool('False')
# Out:
# True
